# %% [markdown]
# # Random Walk
# Random walk is an optimization algorithm which minimizes a given cost function. The advantages of this algorithm are:
#
# - The implementation of this algorithm is very simple.
# - The evaluation of the gradient is not necessary.
#
# The random walk starts at a random position. The cost function at this position is evaluated. From this current position the cost function at a random neighbouring position is evaluated. If this random neighbouring position leads to a smaller cost function, this new position is kept as the starting position of the next iteration.

# %%
import numpy as np

def CostFunction(x):
    return x**2 - 4*x + 5

BestPosition = np.random.randn(1)
BestCost = CostFunction(BestPosition)
for n in range(1000):
    NewPosition = BestPosition + np.random.randn(1)
    NewCost = CostFunction(NewPosition)
    if NewCost < BestCost:
        BestPosition = NewPosition
        BestCost = NewCost
        print(f"New best position: {BestPosition}, New best cost: {BestCost}")
# Out:
# New best position: [0.04442948], New best cost: [4.82425604]
# New best position: [0.17710463], New best cost: [4.32294754]
# New best position: [0.59535127], New best cost: [2.97303807]
# New best position: [0.89160041], New best cost: [2.22854965]
# New best position: [1.89909507], New best cost: [1.01018181]
# New best position: [2.07501525], New best cost: [1.00562729]
# New best position: [2.0360738], New best cost: [1.00130132]
# New best position: [2.01768456], New best cost: [1.00031274]
# New best position: [1.98608757], New best cost: [1.00019356]
# New best position: [2.00899542], New best cost: [1.00008092]
# New best position: [2.00481553], New best cost: [1.00002319]
# New best position: [2.0022463], New best cost: [1.00000505]
